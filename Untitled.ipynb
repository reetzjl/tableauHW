# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7251327f1a37> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling as pp
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
# read in a May2018 dataset to print columns
May2018 = pd.read_csv('JC-201805-citibike-tripdata.csv')

# %%
May2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
June2018 = pd.read_csv('JC-201806-citibike-tripdata.csv')
July2018 = pd.read_csv('JC-201807-citibike-tripdata.csv')
Aug2018 = pd.read_csv('JC-201808-citibike-tripdata.csv')
Sept2018 = pd.read_csv('JC-201809-citibike-tripdata.csv')

# %%
frames = [June2018, July2018, Aug2018, Sept2018]
df = pd.concat(frames)
df = df.reset_index()

# %%
df.head()
# Out:
#    index  tripduration                 starttime                  stoptime  \
# 0      0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1      1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2      2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3      3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4      4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
df = df.reset_index()

# %%
df.starttime[0][:10]
# Out:
# '2018-06-01'

# %%
df['date'] = [x[:10] for x in df.starttime.values]

# %%
df
# Out:
#         level_0  rideid  tripduration                 starttime  \
# 0             0       0           329  2018-06-01 07:07:00.2990
# 1             1       1           259  2018-06-01 08:24:43.8490
# 2             2       2           686  2018-06-01 09:17:49.5730
# 3             3       3           164  2018-06-01 09:44:00.4020
# 4             4       4           769  2018-06-01 09:59:28.7800
# 5             5       5           256  2018-06-01 10:33:02.1100
# 6             6       6           267  2018-06-01 11:33:22.6440
# 7             7       7           258  2018-06-01 12:07:49.8830
# 8             8       8          1247  2018-06-01 12:53:24.8470
# 9             9       9           761  2018-06-01 13:21:09.2160
# 10           10      10           261  2018-06-01 13:29:55.8570
# 11           11      11           294  2018-06-01 13:54:32.1000
# 12           12      12           313  2018-06-01 14:35:06.8030
# 13           13      13           262  2018-06-01 14:57:34.3880
# ...

# %%
df = df.rename(columns={'index': 'rideid'})
df.to_csv('citibike.csv', index=False)
